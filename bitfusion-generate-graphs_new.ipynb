# %% [markdown]
# # Imports

# %%
import pandas
import configparser as ConfigParser
import os
import numpy as np
# %load_ext autoreload
# %autoreload 2
from bitfusion.graph_plot.barchart import BarChart

# %matplotlib inline
import matplotlib

import warnings
warnings.filterwarnings('ignore')

import bitfusion.src.benchmarks.benchmarks as benchmarks
from bitfusion.src.simulator.stats import Stats
from bitfusion.src.simulator.simulator import Simulator
from bitfusion.src.sweep.sweep import SimulatorSweep, check_pandas_or_run
from bitfusion.src.utils.utils import *
from bitfusion.src.optimizer.optimizer import optimize_for_order, get_stats_fast

import dnnweaver2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Constants
# ### We use a batch size of 16

# %%
# ant配置
batch_size = 64
# 默认配置
# batch_size = 16
# batch_size = 32

results_dir = './results'
if not os.path.exists(results_dir):
    os.makedirs(results_dir)

fig_dir = './fig'
if not os.path.exists(fig_dir):
    os.makedirs(fig_dir)

# %% [markdown]
# ### Create a simulator object using the configuration from BitFusion-Eyeriss (bf_e_conf.ini)

# %%
# 初始化+能耗仿真
# # BitFusion configuration file
# 原始样例
# config_file = 'bf_e_conf.ini'
# 测试样例
config_file = 'bf_test_conf.ini'

# ANT configuration file
# config_file = 'conf_ant.ini'

# Create simulator object
verbose = False
# verbose 调试模式启动
# verbose = True


bf_e_sim = Simulator(config_file, verbose)

# 得把这个解决
bf_e_energy_costs = bf_e_sim.get_energy_cost()

print(bf_e_sim)

energy_tuple = bf_e_energy_costs
print('')
print('*'*50)
print(energy_tuple)
# Out:
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
#
# NM_MAX_MIN_参数适配: 0
# 修正后,lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 2, 'N': 4, 'M': 4}
#
# Simulator object
# 	Max supported precision: 8
# 	Min supported precision: 2
# 	Systolic array size: 16 -inputs x 32 -outputs
# 	Wbuf size: 65,536 Bytes
# 	Ibuf size: 32,768 Bytes
# 	Obuf size: 16,384 Bytes
# Double buffering enabled. Sizes of SRAM are halved
#
# **************************************************
# Energy costs for BitFusion
# Core dynamic energy : 235.104 pJ/cycle (for entire systolic array)
# WBUF Read energy    : 0.021 pJ/bit
# WBUF Write energy   : 0.029 pJ/bit
# IBUF Read energy    : 0.059 pJ/bit
# IBUF Write energy   : 0.114 pJ/bit
# OBUF Read energy    : 0.033 pJ/bit
# OBUF Write energy   : 0.073 pJ/bit

# %% [markdown]
# ### Generate BitFusion numbers

# %%
# csv表的列头
sim_sweep_columns = ['N', 'M',
        'Max Precision (bits)', 'Min Precision (bits)',
        'Network', 'Layer',
        'Cycles', 'Memory wait cycles',
        'WBUF Read', 'WBUF Write',
        'OBUF Read', 'OBUF Write',
        'IBUF Read', 'IBUF Write',
        'DRAM Read', 'DRAM Write',
        'Bandwidth (bits/cycle)',
        'WBUF Size (bits)', 'OBUF Size (bits)', 'IBUF Size (bits)',
        'Batch size']

# bf_e_sim_sweep_csv = os.path.join(results_dir, 'bitfusion-eyeriss-sim-sweep.csv')
bf_e_sim_sweep_csv = os.path.join(results_dir, 'bitfusion-8t28_test-sim-sweep.csv')


#对文件的存在进行判断
# if os.path.exists(bf_e_sim_sweep_csv):
#     bf_e_sim_sweep_df = pandas.read_csv(bf_e_sim_sweep_csv)
# else:
#     #0行21列 空表
#     bf_e_sim_sweep_df = pandas.DataFrame(columns=sim_sweep_columns)
# print('Got BitFusion Eyeriss, Numbers')

# 直接生成新表
bf_e_sim_sweep_df = pandas.DataFrame(columns=sim_sweep_columns)




bf_e_results = check_pandas_or_run(bf_e_sim, bf_e_sim_sweep_df,
        bf_e_sim_sweep_csv, batch_size=batch_size)

# 'groupby()'方法对 'Network' 列进行分组，并使用 agg() 方法对每个组进行聚合操作，将聚合结果求和。
bf_e_results = bf_e_results.groupby('Network',as_index=False).agg(np.sum)

#面积区域的放置存在问题,仿真的参数表需要重新设置

# area_stats = bf_e_sim.get_area()

# print('area_stats',area_stats)

#此时已经得到了Bit Fusion的 能耗+Benchmarks的次数+面积
# Out:
# INFO:bitfusion.src.sweep.sweep.Simulator:Simulating Benchmark: AlexNet
# INFO:bitfusion.src.sweep.sweep.Simulator:N x M = 16 x 32
# INFO:bitfusion.src.sweep.sweep.Simulator:Max Precision (bits): 8
# INFO:bitfusion.src.sweep.sweep.Simulator:Min Precision (bits): 8
# INFO:bitfusion.src.sweep.sweep.Simulator:Batch size: 64
# INFO:bitfusion.src.sweep.sweep.Simulator:Bandwidth (bits/cycle): 1920
# ./conf.ini
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# B/b: Range 16, stride {'wgt': 0, 'act': 154587, 'out': 145200}
#  | OW/ow: Range 55, stride {'wgt': 0, 'act': 4, 'out': 1}
#  |  | OH/oh: Range 55, stride {'wgt': 0, 'act': 908, 'out': 55}
#  |  |  | Out RD: addr 0, size 1536, stride [145200, 1, 55], level: 3
#  |  |  | Act RD: addr 0, size 1024, stride [154587, 4, 908], level: 3
#  |  |  | Out WR: addr 0, size 1536, stride [145200, 1, 55], level: 3
# **************************************************
# Wgt RD: addr 0, size 70656, stride [0, 0, 0], level: 0
# **************************************************
#
# best_tiling {'B/b': (16, 1), 'OW/ow': (55, 1), 'OH/oh': (55, 1), 'IC/ic': (1, 3), 'OC/oc': (1, 48)}
# best_order ('IC/ic', 'B/b', 'OW/ow', 'OH/oh', 'OC/oc')
# Total Cycles: 2,226,442
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# B/b: Range 16, stride {'wgt': 0, 'act': 154587, 'out': 145200}
#  | OW/ow: Range 55, stride {'wgt': 0, 'act': 4, 'out': 1}
#  |  | OH/oh: Range 55, stride {'wgt': 0, 'act': 908, 'out': 55}
#  |  |  | Out RD: addr 0, size 1536, stride [145200, 1, 55], level: 3
#  |  |  | Act RD: addr 0, size 1024, stride [154587, 4, 908], level: 3
#  |  |  | Out WR: addr 0, size 1536, stride [145200, 1, 55], level: 3
# **************************************************
# Wgt RD: addr 0, size 70656, stride [0, 0, 0], level: 0
# **************************************************
#
# best_tiling {'B/b': (16, 1), 'OW/ow': (55, 1), 'OH/oh': (55, 1), 'IC/ic': (1, 3), 'OC/oc': (1, 48)}
# best_order ('IC/ic', 'B/b', 'OW/ow', 'OH/oh', 'OC/oc')
# Total Cycles: 2,226,442
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# OW/ow: Range 27, stride {'wgt': 0, 'act': 1, 'out': 1}
#  | B/b: Range 8, stride {'wgt': 0, 'act': 92256, 'out': 186624}
#  |  | Act RD: addr 0, size 20736, stride [1, 92256, 0, 31, 15376], level: 2
#  |  | OC/oc: Range 2, stride {'wgt': 76800, 'act': 0, 'out': 46656}
#  |  |  | OH/oh: Range 27, stride {'wgt': 0, 'act': 31, 'out': 27}
#  |  |  |  | Out RD: addr 0, size 4096, stride [1, 186624, 46656, 27, 0], level: 4
#  |  |  |  | IC/ic: Range 3, stride {'wgt': 400, 'act': 15376, 'out': 0}
#  |  |  |  |  | Wgt RD: addr 0, size 102400, stride [0, 0, 76800, 0, 400], level: 5
#  |  |  |  | Out WR: addr 0, size 4096, stride [1, 186624, 46656, 27, 0], level: 4
# **************************************************
#
# best_tiling {'B/b': (8, 2), 'OW/ow': (27, 1), 'OH/oh': (27, 1), 'IC/ic': (3, 16), 'OC/oc': (2, 64)}
# best_order ('OW/ow', 'B/b', 'OC/oc', 'OH/oh', 'IC/ic')
# Total Cycles: 3,499,264
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# OW/ow: Range 27, stride {'wgt': 0, 'act': 1, 'out': 1}
#  | B/b: Range 8, stride {'wgt': 0, 'act': 92256, 'out': 186624}
#  |  | Act RD: addr 0, size 20736, stride [1, 92256, 0, 31, 15376], level: 2
#  |  | OC/oc: Range 2, stride {'wgt': 76800, 'act': 0, 'out': 46656}
#  |  |  | OH/oh: Range 27, stride {'wgt': 0, 'act': 31, 'out': 27}
#  |  |  |  | Out RD: addr 0, size 4096, stride [1, 186624, 46656, 27, 0], level: 4
#  |  |  |  | IC/ic: Range 3, stride {'wgt': 400, 'act': 15376, 'out': 0}
#  |  |  |  |  | Wgt RD: addr 0, size 102400, stride [0, 0, 76800, 0, 400], level: 5
#  |  |  |  | Out WR: addr 0, size 4096, stride [1, 186624, 46656, 27, 0], level: 4
# **************************************************
#
# best_tiling {'B/b': (8, 2), 'OW/ow': (27, 1), 'OH/oh': (27, 1), 'IC/ic': (3, 16), 'OC/oc': (2, 64)}
# best_order ('OW/ow', 'B/b', 'OC/oc', 'OH/oh', 'IC/ic')
# Total Cycles: 3,499,264
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# OW/ow: Range 13, stride {'wgt': 0, 'act': 1, 'out': 1}
#  | OH/oh: Range 13, stride {'wgt': 0, 'act': 15, 'out': 13}
#  |  | Act RD: addr 0, size 16384, stride [1, 15, 0, 3600], level: 2
#  |  | OC/oc: Range 6, stride {'wgt': 73728, 'act': 0, 'out': 5408}
#  |  |  | Out RD: addr 0, size 16384, stride [1, 13, 5408, 0], level: 3
#  |  |  | IC/ic: Range 16, stride {'wgt': 144, 'act': 3600, 'out': 0}
#  |  |  |  | Wgt RD: addr 0, size 18432, stride [0, 0, 73728, 144], level: 4
#  |  |  | Out WR: addr 0, size 16384, stride [1, 13, 5408, 0], level: 3
# **************************************************
#
# best_tiling {'B/b': (1, 16), 'OW/ow': (13, 1), 'OH/oh': (13, 1), 'IC/ic': (16, 16), 'OC/oc': (6, 32)}
# best_order ('OW/ow', 'OH/oh', 'B/b', 'OC/oc', 'IC/ic')
# Total Cycles: 2,336,288
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# OW/ow: Range 13, stride {'wgt': 0, 'act': 1, 'out': 1}
#  | OH/oh: Range 13, stride {'wgt': 0, 'act': 15, 'out': 13}
#  |  | Act RD: addr 0, size 16384, stride [1, 15, 0, 3600], level: 2
#  |  | OC/oc: Range 6, stride {'wgt': 73728, 'act': 0, 'out': 5408}
#  |  |  | Out RD: addr 0, size 16384, stride [1, 13, 5408, 0], level: 3
#  |  |  | IC/ic: Range 16, stride {'wgt': 144, 'act': 3600, 'out': 0}
#  |  |  |  | Wgt RD: addr 0, size 18432, stride [0, 0, 73728, 144], level: 4
#  |  |  | Out WR: addr 0, size 16384, stride [1, 13, 5408, 0], level: 3
# **************************************************
#
# best_tiling {'B/b': (1, 16), 'OW/ow': (13, 1), 'OH/oh': (13, 1), 'IC/ic': (16, 16), 'OC/oc': (6, 32)}
# best_order ('OW/ow', 'OH/oh', 'B/b', 'OC/oc', 'IC/ic')
# Total Cycles: 2,336,288
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# OH/oh: Range 13, stride {'wgt': 0, 'act': 15, 'out': 13}
#  | B/b: Range 8, stride {'wgt': 0, 'act': 86400, 'out': 64896}
#  |  | Act RD: addr 0, size 19968, stride [15, 86400, 1, 0, 3600], level: 2
#  |  | OW/ow: Range 13, stride {'wgt': 0, 'act': 1, 'out': 1}
#  |  |  | Out RD: addr 0, size 12288, stride [13, 64896, 1, 10816, 0], level: 3
#  |  |  | OC/oc: Range 3, stride {'wgt': 110592, 'act': 0, 'out': 10816}
#  |  |  |  | IC/ic: Range 12, stride {'wgt': 144, 'act': 3600, 'out': 0}
#  |  |  |  |  | Wgt RD: addr 0, size 36864, stride [0, 0, 0, 110592, 144], level: 5
#  |  |  | Out WR: addr 0, size 12288, stride [13, 64896, 1, 10816, 0], level: 3
# **************************************************
#
# best_tiling {'B/b': (8, 2), 'OW/ow': (13, 1), 'OH/oh': (13, 1), 'IC/ic': (12, 16), 'OC/oc': (3, 64)}
# best_order ('OH/oh', 'B/b', 'OW/ow', 'OC/oc', 'IC/ic')
# Total Cycles: 1,752,232
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# OH/oh: Range 13, stride {'wgt': 0, 'act': 15, 'out': 13}
#  | B/b: Range 8, stride {'wgt': 0, 'act': 86400, 'out': 64896}
#  |  | Act RD: addr 0, size 19968, stride [15, 86400, 1, 0, 3600], level: 2
#  |  | OW/ow: Range 13, stride {'wgt': 0, 'act': 1, 'out': 1}
#  |  |  | Out RD: addr 0, size 12288, stride [13, 64896, 1, 10816, 0], level: 3
#  |  |  | OC/oc: Range 3, stride {'wgt': 110592, 'act': 0, 'out': 10816}
#  |  |  |  | IC/ic: Range 12, stride {'wgt': 144, 'act': 3600, 'out': 0}
#  |  |  |  |  | Wgt RD: addr 0, size 36864, stride [0, 0, 0, 110592, 144], level: 5
#  |  |  | Out WR: addr 0, size 12288, stride [13, 64896, 1, 10816, 0], level: 3
# **************************************************
#
# best_tiling {'B/b': (8, 2), 'OW/ow': (13, 1), 'OH/oh': (13, 1), 'IC/ic': (12, 16), 'OC/oc': (3, 64)}
# best_order ('OH/oh', 'B/b', 'OW/ow', 'OC/oc', 'IC/ic')
# Total Cycles: 1,752,232
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# OH/oh: Range 13, stride {'wgt': 0, 'act': 15, 'out': 13}
#  | B/b: Range 8, stride {'wgt': 0, 'act': 86400, 'out': 43264}
#  |  | Act RD: addr 0, size 19968, stride [15, 86400, 1, 0, 3600], level: 2
#  |  | OW/ow: Range 13, stride {'wgt': 0, 'act': 1, 'out': 1}
#  |  |  | Out RD: addr 0, size 8192, stride [13, 43264, 1, 10816, 0], level: 3
#  |  |  | OC/oc: Range 2, stride {'wgt': 110592, 'act': 0, 'out': 10816}
#  |  |  |  | IC/ic: Range 12, stride {'wgt': 144, 'act': 3600, 'out': 0}
#  |  |  |  |  | Wgt RD: addr 0, size 36864, stride [0, 0, 0, 110592, 144], level: 5
#  |  |  | Out WR: addr 0, size 8192, stride [13, 43264, 1, 10816, 0], level: 3
# **************************************************
#
# best_tiling {'B/b': (8, 2), 'OW/ow': (13, 1), 'OH/oh': (13, 1), 'IC/ic': (12, 16), 'OC/oc': (2, 64)}
# best_order ('OH/oh', 'B/b', 'OW/ow', 'OC/oc', 'IC/ic')
# Total Cycles: 1,168,164
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# OH/oh: Range 13, stride {'wgt': 0, 'act': 15, 'out': 13}
#  | B/b: Range 8, stride {'wgt': 0, 'act': 86400, 'out': 43264}
#  |  | Act RD: addr 0, size 19968, stride [15, 86400, 1, 0, 3600], level: 2
#  |  | OW/ow: Range 13, stride {'wgt': 0, 'act': 1, 'out': 1}
#  |  |  | Out RD: addr 0, size 8192, stride [13, 43264, 1, 10816, 0], level: 3
#  |  |  | OC/oc: Range 2, stride {'wgt': 110592, 'act': 0, 'out': 10816}
#  |  |  |  | IC/ic: Range 12, stride {'wgt': 144, 'act': 3600, 'out': 0}
#  |  |  |  |  | Wgt RD: addr 0, size 36864, stride [0, 0, 0, 110592, 144], level: 5
#  |  |  | Out WR: addr 0, size 8192, stride [13, 43264, 1, 10816, 0], level: 3
# **************************************************
#
# best_tiling {'B/b': (8, 2), 'OW/ow': (13, 1), 'OH/oh': (13, 1), 'IC/ic': (12, 16), 'OC/oc': (2, 64)}
# best_order ('OH/oh', 'B/b', 'OW/ow', 'OC/oc', 'IC/ic')
# Total Cycles: 1,168,164
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# B/b: Range 4, stride {'wgt': 0, 'act': 36864, 'out': 16384}
#  | OC/oc: Range 128, stride {'wgt': 294912, 'act': 0, 'out': 32}
#  |  | Out RD: addr 0, size 4096, stride [16384, 32, 0], level: 2
#  |  | IC/ic: Range 576, stride {'wgt': 16, 'act': 16, 'out': 0}
#  |  |  | Act RD: addr 0, size 256, stride [36864, 0, 16], level: 3
#  |  |  | Wgt RD: addr 0, size 2048, stride [0, 294912, 16], level: 3
#  |  | Out WR: addr 0, size 4096, stride [16384, 32, 0], level: 2
# **************************************************
#
# best_tiling {'B/b': (4, 4), 'OW/ow': (1, 1), 'OH/oh': (1, 1), 'IC/ic': (576, 16), 'OC/oc': (128, 32)}
# best_order ('OW/ow', 'OH/oh', 'B/b', 'OC/oc', 'IC/ic')
# Total Cycles: 1,179,655
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# IC/ic: Range 128, stride {'wgt': 32, 'act': 32, 'out': 0}
#  | Act RD: addr 0, size 2048, stride [32, 16384, 0], level: 1
#  | B/b: Range 4, stride {'wgt': 0, 'act': 16384, 'out': 16384}
#  |  | OC/oc: Range 128, stride {'wgt': 131072, 'act': 0, 'out': 32}
#  |  |  | Out RD: addr 0, size 4096, stride [0, 16384, 32], level: 3
#  |  |  | Wgt RD: addr 0, size 4096, stride [32, 0, 131072], level: 3
#  |  |  | Out WR: addr 0, size 4096, stride [0, 16384, 32], level: 3
# **************************************************
#
# best_tiling {'B/b': (4, 4), 'OW/ow': (1, 1), 'OH/oh': (1, 1), 'IC/ic': (128, 32), 'OC/oc': (128, 32)}
# best_order ('IC/ic', 'B/b', 'OW/ow', 'OH/oh', 'OC/oc')
# Total Cycles: 524,297
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# INFO:bitfusion.src.sweep.sweep.Simulator:Simulating Benchmark: SVHN
# INFO:bitfusion.src.sweep.sweep.Simulator:N x M = 16 x 32
# INFO:bitfusion.src.sweep.sweep.Simulator:Max Precision (bits): 8
# INFO:bitfusion.src.sweep.sweep.Simulator:Min Precision (bits): 8
# INFO:bitfusion.src.sweep.sweep.Simulator:Batch size: 64
# INFO:bitfusion.src.sweep.sweep.Simulator:Bandwidth (bits/cycle): 1920
# best_instructions **************************************************
# B/b: Range 2, stride {'wgt': 0, 'act': 32768, 'out': 8000}
#  | OC/oc: Range 32, stride {'wgt': 131072, 'act': 0, 'out': 32}
#  |  | Out RD: addr 0, size 8192, stride [8000, 32, 0], level: 2
#  |  | IC/ic: Range 256, stride {'wgt': 16, 'act': 16, 'out': 0}
#  |  |  | Act RD: addr 0, size 1024, stride [32768, 0, 16], level: 3
#  |  |  | Wgt RD: addr 0, size 4096, stride [0, 131072, 16], level: 3
#  |  | Out WR: addr 0, size 8192, stride [8000, 32, 0], level: 2
# **************************************************
#
# best_tiling {'B/b': (2, 8), 'OW/ow': (1, 1), 'OH/oh': (1, 1), 'IC/ic': (256, 16), 'OC/oc': (32, 32)}
# best_order ('OW/ow', 'OH/oh', 'B/b', 'OC/oc', 'IC/ic')
# Total Cycles: 131,084
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# B/b: Range 8, stride {'wgt': 0, 'act': 6936, 'out': 131072}
#  | OW/ow: Range 32, stride {'wgt': 0, 'act': 1, 'out': 1}
#  |  | Act RD: addr 0, size 8192, stride [6936, 1, 34, 0], level: 2
#  |  | OH/oh: Range 32, stride {'wgt': 0, 'act': 34, 'out': 32}
#  |  |  | Out RD: addr 0, size 4096, stride [131072, 1, 32, 32768], level: 3
#  |  |  | OC/oc: Range 2, stride {'wgt': 864, 'act': 0, 'out': 32768}
#  |  |  | Out WR: addr 0, size 4096, stride [131072, 1, 32, 32768], level: 3
# **************************************************
# Wgt RD: addr 0, size 2048, stride [0, 0, 0, 864], level: 0
# **************************************************
#
# best_tiling {'B/b': (8, 2), 'OW/ow': (32, 1), 'OH/oh': (32, 1), 'IC/ic': (1, 3), 'OC/oc': (2, 32)}
# best_order ('IC/ic', 'B/b', 'OW/ow', 'OH/oh', 'OC/oc')
# Total Cycles: 65,550
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# IC/ic: Range 4, stride {'wgt': 144, 'act': 18496, 'out': 0}
#  | B/b: Range 8, stride {'wgt': 0, 'act': 147968, 'out': 131072}
#  |  | OW/ow: Range 32, stride {'wgt': 0, 'act': 1, 'out': 1}
#  |  |  | Act RD: addr 0, size 1024, stride [18496, 147968, 1, 34, 0], level: 3
#  |  |  | OH/oh: Range 32, stride {'wgt': 0, 'act': 34, 'out': 32}
#  |  |  |  | Out RD: addr 0, size 4096, stride [0, 131072, 1, 32, 32768], level: 4
#  |  |  |  | OC/oc: Range 2, stride {'wgt': 18432, 'act': 0, 'out': 32768}
#  |  |  |  | Out WR: addr 0, size 4096, stride [0, 131072, 1, 32, 32768], level: 4
# **************************************************
# Wgt RD: addr 0, size 36864, stride [144, 0, 0, 0, 18432], level: 0
# **************************************************
#
# best_tiling {'B/b': (8, 2), 'OW/ow': (32, 1), 'OH/oh': (32, 1), 'IC/ic': (4, 16), 'OC/oc': (2, 32)}
# best_order ('IC/ic', 'B/b', 'OW/ow', 'OH/oh', 'OC/oc')
# Total Cycles: 1,179,678
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# IC/ic: Range 2, stride {'wgt': 288, 'act': 10368, 'out': 0}
#  | Wgt RD: addr 0, size 36864, stride [288, 0, 0, 0, 18432], level: 1
#  | B/b: Range 8, stride {'wgt': 0, 'act': 41472, 'out': 65536}
#  |  | Act RD: addr 0, size 8192, stride [10368, 41472, 1, 18, 0], level: 2
#  |  | OW/ow: Range 16, stride {'wgt': 0, 'act': 1, 'out': 1}
#  |  |  | OH/oh: Range 16, stride {'wgt': 0, 'act': 18, 'out': 16}
#  |  |  |  | Out RD: addr 0, size 8192, stride [0, 65536, 1, 16, 8192], level: 4
#  |  |  |  | OC/oc: Range 4, stride {'wgt': 18432, 'act': 0, 'out': 8192}
#  |  |  |  | Out WR: addr 0, size 8192, stride [0, 65536, 1, 16, 8192], level: 4
# **************************************************
#
# best_tiling {'B/b': (8, 2), 'OW/ow': (16, 1), 'OH/oh': (16, 1), 'IC/ic': (2, 32), 'OC/oc': (4, 32)}
# best_order ('IC/ic', 'B/b', 'OW/ow', 'OH/oh', 'OC/oc')
# Total Cycles: 589,877
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# OC/oc: Range 4, stride {'wgt': 36864, 'act': 0, 'out': 8192}
#  | Wgt RD: addr 0, size 36864, stride [36864, 0, 0, 0], level: 1
#  | B/b: Range 2, stride {'wgt': 0, 'act': 331776, 'out': 262144}
#  |  | OH/oh: Range 16, stride {'wgt': 0, 'act': 18, 'out': 16}
#  |  |  | Act RD: addr 0, size 2048, stride [0, 331776, 18, 1], level: 3
#  |  |  | OW/ow: Range 16, stride {'wgt': 0, 'act': 1, 'out': 1}
#  |  |  |  | Out RD: addr 0, size 8192, stride [8192, 262144, 16, 1], level: 4
#  |  |  |  | Out WR: addr 0, size 8192, stride [8192, 262144, 16, 1], level: 4
# **************************************************
#
# best_tiling {'B/b': (2, 8), 'OW/ow': (16, 1), 'OH/oh': (16, 1), 'IC/ic': (1, 128), 'OC/oc': (4, 32)}
# best_order ('OC/oc', 'B/b', 'IC/ic', 'OH/oh', 'OW/ow')
# Total Cycles: 1,179,739
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# OC/oc: Range 8, stride {'wgt': 36864, 'act': 0, 'out': 2048}
#  | Wgt RD: addr 0, size 36864, stride [36864, 0, 0, 0], level: 1
#  | OH/oh: Range 8, stride {'wgt': 0, 'act': 10, 'out': 8}
#  |  | B/b: Range 16, stride {'wgt': 0, 'act': 12800, 'out': 16384}
#  |  |  | Out RD: addr 0, size 8192, stride [2048, 8, 16384, 1], level: 3
#  |  |  | OW/ow: Range 8, stride {'wgt': 0, 'act': 1, 'out': 1}
#  |  |  | Out WR: addr 0, size 8192, stride [2048, 8, 16384, 1], level: 3
# **************************************************
# Act RD: addr 0, size 16384, stride [0, 10, 12800, 1], level: 0
# **************************************************
#
# best_tiling {'B/b': (16, 1), 'OW/ow': (8, 1), 'OH/oh': (8, 1), 'IC/ic': (1, 128), 'OC/oc': (8, 32)}
# best_order ('OC/oc', 'OH/oh', 'B/b', 'IC/ic', 'OW/ow')
# Total Cycles: 589,858
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# OH/oh: Range 4, stride {'wgt': 0, 'act': 10, 'out': 8}
#  | OC/oc: Range 2, stride {'wgt': 294912, 'act': 0, 'out': 8192}
#  |  | OW/ow: Range 4, stride {'wgt': 0, 'act': 2, 'out': 2}
#  |  |  | Act RD: addr 0, size 16384, stride [10, 0, 2, 25600, 1600], level: 3
#  |  |  | B/b: Range 16, stride {'wgt': 0, 'act': 25600, 'out': 16384}
#  |  |  |  | Out RD: addr 0, size 16384, stride [8, 8192, 2, 16384, 0], level: 4
#  |  |  |  | IC/ic: Range 16, stride {'wgt': 144, 'act': 1600, 'out': 0}
#  |  |  |  |  | Wgt RD: addr 0, size 18432, stride [0, 294912, 0, 0, 144], level: 5
#  |  |  |  | Out WR: addr 0, size 16384, stride [8, 8192, 2, 16384, 0], level: 4
# **************************************************
#
# best_tiling {'B/b': (16, 1), 'OW/ow': (4, 2), 'OH/oh': (4, 2), 'IC/ic': (16, 16), 'OC/oc': (2, 128)}
# best_order ('OH/oh', 'OC/oc', 'OW/ow', 'B/b', 'IC/ic')
# Total Cycles: 1,179,680
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# OC/oc: Range 4, stride {'wgt': 1048576, 'act': 0, 'out': 256}
#  | B/b: Range 16, stride {'wgt': 0, 'act': 4096, 'out': 1024}
#  |  | Out RD: addr 0, size 8192, stride [256, 1024, 0], level: 2
#  |  | Act RD: addr 0, size 4096, stride [0, 4096, 16], level: 2
#  |  | IC/ic: Range 256, stride {'wgt': 16, 'act': 16, 'out': 0}
#  |  |  | Wgt RD: addr 0, size 4096, stride [1048576, 0, 16], level: 3
#  |  | Out WR: addr 0, size 8192, stride [256, 1024, 0], level: 2
# **************************************************
#
# best_tiling {'B/b': (16, 1), 'OW/ow': (1, 1), 'OH/oh': (1, 1), 'IC/ic': (256, 16), 'OC/oc': (4, 256)}
# best_order ('OC/oc', 'B/b', 'IC/ic', 'OH/oh', 'OW/ow')
# Total Cycles: 131,118
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# IC/ic: Range 2, stride {'wgt': 512, 'act': 512, 'out': 0}
#  | B/b: Range 4, stride {'wgt': 0, 'act': 4096, 'out': 4096}
#  |  | OC/oc: Range 32, stride {'wgt': 32768, 'act': 0, 'out': 32}
#  |  |  | Out RD: addr 0, size 4096, stride [0, 4096, 32], level: 3
#  |  |  | Wgt RD: addr 0, size 16384, stride [512, 0, 32768], level: 3
#  |  |  | Out WR: addr 0, size 4096, stride [0, 4096, 32], level: 3
# **************************************************
# Act RD: addr 0, size 16384, stride [512, 4096, 0], level: 0
# **************************************************
#
# best_tiling {'B/b': (4, 4), 'OW/ow': (1, 1), 'OH/oh': (1, 1), 'IC/ic': (2, 512), 'OC/oc': (32, 32)}
# best_order ('IC/ic', 'B/b', 'OW/ow', 'OH/oh', 'OC/oc')
# Total Cycles: 32,791
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# INFO:bitfusion.src.sweep.sweep.Simulator:Simulating Benchmark: CIFAR10
# INFO:bitfusion.src.sweep.sweep.Simulator:N x M = 16 x 32
# INFO:bitfusion.src.sweep.sweep.Simulator:Max Precision (bits): 8
# INFO:bitfusion.src.sweep.sweep.Simulator:Min Precision (bits): 8
# INFO:bitfusion.src.sweep.sweep.Simulator:Batch size: 64
# INFO:bitfusion.src.sweep.sweep.Simulator:Bandwidth (bits/cycle): 1920
# best_instructions **************************************************
# B/b: Range 16, stride {'wgt': 0, 'act': 1024, 'out': 10}
# **************************************************
# Wgt RD: addr 0, size 32768, stride [0], level: 0
# **************************************************
# Act RD: addr 0, size 16384, stride [1024], level: 0
# **************************************************
# Out RD: addr 0, size 5120, stride [10], level: 0
# **************************************************
# Out WR: addr 0, size 5120, stride [10], level: 0
# **************************************************
#
# best_tiling {'B/b': (16, 1), 'OW/ow': (1, 1), 'OH/oh': (1, 1), 'IC/ic': (1, 1024), 'OC/oc': (1, 10)}
# best_order ('IC/ic', 'B/b', 'OW/ow', 'OH/oh', 'OC/oc')
# Total Cycles: 1,056
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# B/b: Range 16, stride {'wgt': 0, 'act': 3468, 'out': 131072}
#  | OW/ow: Range 32, stride {'wgt': 0, 'act': 1, 'out': 1}
#  |  | Act RD: addr 0, size 4096, stride [3468, 1, 34, 0], level: 2
#  |  | OH/oh: Range 32, stride {'wgt': 0, 'act': 34, 'out': 32}
#  |  |  | Out RD: addr 0, size 4096, stride [131072, 1, 32, 32768], level: 3
#  |  |  | OC/oc: Range 4, stride {'wgt': 864, 'act': 0, 'out': 32768}
#  |  |  | Out WR: addr 0, size 4096, stride [131072, 1, 32, 32768], level: 3
# **************************************************
# Wgt RD: addr 0, size 32768, stride [0, 0, 0, 864], level: 0
# **************************************************
#
# best_tiling {'B/b': (16, 1), 'OW/ow': (32, 1), 'OH/oh': (32, 1), 'IC/ic': (1, 3), 'OC/oc': (4, 32)}
# best_order ('IC/ic', 'B/b', 'OW/ow', 'OH/oh', 'OC/oc')
# Total Cycles: 131,098
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# IC/ic: Range 8, stride {'wgt': 144, 'act': 18496, 'out': 0}
#  | Wgt RD: addr 0, size 36864, stride [144, 0, 0, 0, 36864], level: 1
#  | B/b: Range 16, stride {'wgt': 0, 'act': 147968, 'out': 131072}
#  |  | OW/ow: Range 32, stride {'wgt': 0, 'act': 1, 'out': 1}
#  |  |  | Act RD: addr 0, size 1024, stride [18496, 147968, 1, 34, 0], level: 3
#  |  |  | OH/oh: Range 32, stride {'wgt': 0, 'act': 34, 'out': 32}
#  |  |  |  | Out RD: addr 0, size 4096, stride [0, 131072, 1, 32, 32768], level: 4
#  |  |  |  | OC/oc: Range 4, stride {'wgt': 36864, 'act': 0, 'out': 32768}
#  |  |  |  | Out WR: addr 0, size 4096, stride [0, 131072, 1, 32, 32768], level: 4
# **************************************************
#
# best_tiling {'B/b': (16, 1), 'OW/ow': (32, 1), 'OH/oh': (32, 1), 'IC/ic': (8, 16), 'OC/oc': (4, 32)}
# best_order ('IC/ic', 'B/b', 'OW/ow', 'OH/oh', 'OC/oc')
# Total Cycles: 4,718,622
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# IC/ic: Range 2, stride {'wgt': 576, 'act': 20736, 'out': 0}
#  | OC/oc: Range 8, stride {'wgt': 36864, 'act': 0, 'out': 8192}
#  |  | Wgt RD: addr 0, size 36864, stride [576, 36864, 0, 0, 0], level: 2
#  |  | OH/oh: Range 16, stride {'wgt': 0, 'act': 18, 'out': 16}
#  |  |  | Act RD: addr 0, size 8192, stride [20736, 0, 18, 331776, 1], level: 3
#  |  |  | B/b: Range 2, stride {'wgt': 0, 'act': 331776, 'out': 524288}
#  |  |  |  | OW/ow: Range 16, stride {'wgt': 0, 'act': 1, 'out': 1}
#  |  |  |  |  | Out RD: addr 0, size 8192, stride [0, 8192, 16, 524288, 1], level: 5
#  |  |  |  |  | Out WR: addr 0, size 8192, stride [0, 8192, 16, 524288, 1], level: 5
# **************************************************
#
# best_tiling {'B/b': (2, 8), 'OW/ow': (16, 1), 'OH/oh': (16, 1), 'IC/ic': (2, 64), 'OC/oc': (8, 32)}
# best_order ('IC/ic', 'OC/oc', 'OH/oh', 'B/b', 'OW/ow')
# Total Cycles: 2,359,330
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# OC/oc: Range 4, stride {'wgt': 147456, 'act': 0, 'out': 16384}
#  | IC/ic: Range 16, stride {'wgt': 144, 'act': 5184, 'out': 0}
#  |  | Wgt RD: addr 0, size 18432, stride [147456, 144, 0, 0, 0], level: 2
#  |  | OH/oh: Range 8, stride {'wgt': 0, 'act': 18, 'out': 16}
#  |  |  | Act RD: addr 0, size 16384, stride [0, 5184, 18, 2, 82944], level: 3
#  |  |  | OW/ow: Range 8, stride {'wgt': 0, 'act': 2, 'out': 2}
#  |  |  |  | B/b: Range 16, stride {'wgt': 0, 'act': 82944, 'out': 65536}
#  |  |  |  |  | Out RD: addr 0, size 8192, stride [16384, 0, 16, 2, 65536], level: 5
#  |  |  |  |  | Out WR: addr 0, size 8192, stride [16384, 0, 16, 2, 65536], level: 5
# **************************************************
#
# best_tiling {'B/b': (16, 1), 'OW/ow': (8, 2), 'OH/oh': (8, 2), 'IC/ic': (16, 16), 'OC/oc': (4, 64)}
# best_order ('OC/oc', 'IC/ic', 'OH/oh', 'OW/ow', 'B/b')
# Total Cycles: 4,718,621
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# IC/ic: Range 8, stride {'wgt': 288, 'act': 3200, 'out': 0}
#  | OH/oh: Range 4, stride {'wgt': 0, 'act': 10, 'out': 8}
#  |  | Act RD: addr 0, size 8192, stride [3200, 10, 51200, 2, 0], level: 2
#  |  | B/b: Range 8, stride {'wgt': 0, 'act': 51200, 'out': 65536}
#  |  |  | OW/ow: Range 4, stride {'wgt': 0, 'act': 2, 'out': 2}
#  |  |  |  | OC/oc: Range 16, stride {'wgt': 73728, 'act': 0, 'out': 2048}
#  |  |  |  |  | Out RD: addr 0, size 8192, stride [0, 8, 65536, 2, 2048], level: 5
#  |  |  |  |  | Wgt RD: addr 0, size 18432, stride [288, 0, 0, 0, 73728], level: 5
#  |  |  |  |  | Out WR: addr 0, size 8192, stride [0, 8, 65536, 2, 2048], level: 5
# **************************************************
#
# best_tiling {'B/b': (8, 2), 'OW/ow': (4, 2), 'OH/oh': (4, 2), 'IC/ic': (8, 32), 'OC/oc': (16, 32)}
# best_order ('IC/ic', 'OH/oh', 'B/b', 'OW/ow', 'OC/oc')
# Total Cycles: 2,359,325
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# OH/oh: Range 8, stride {'wgt': 0, 'act': 10, 'out': 8}
#  | OW/ow: Range 8, stride {'wgt': 0, 'act': 1, 'out': 1}
#  |  | Act RD: addr 0, size 8192, stride [10, 1, 3200, 409600, 0], level: 2
#  |  | IC/ic: Range 16, stride {'wgt': 288, 'act': 3200, 'out': 0}
#  |  |  | B/b: Range 2, stride {'wgt': 0, 'act': 409600, 'out': 262144}
#  |  |  |  | OC/oc: Range 16, stride {'wgt': 147456, 'act': 0, 'out': 2048}
#  |  |  |  |  | Out RD: addr 0, size 8192, stride [8, 1, 0, 262144, 2048], level: 5
#  |  |  |  |  | Wgt RD: addr 0, size 18432, stride [0, 0, 288, 0, 147456], level: 5
#  |  |  |  |  | Out WR: addr 0, size 8192, stride [8, 1, 0, 262144, 2048], level: 5
# **************************************************
#
# best_tiling {'B/b': (2, 8), 'OW/ow': (8, 1), 'OH/oh': (8, 1), 'IC/ic': (16, 32), 'OC/oc': (16, 32)}
# best_order ('OH/oh', 'OW/ow', 'IC/ic', 'B/b', 'OC/oc')
# Total Cycles: 4,718,616
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# IC/ic: Range 32, stride {'wgt': 256, 'act': 256, 'out': 0}
#  | Act RD: addr 0, size 8192, stride [256, 32768, 0], level: 1
#  | B/b: Range 4, stride {'wgt': 0, 'act': 32768, 'out': 4096}
#  |  | OC/oc: Range 32, stride {'wgt': 262144, 'act': 0, 'out': 32}
#  |  |  | Out RD: addr 0, size 4096, stride [0, 4096, 32], level: 3
#  |  |  | Wgt RD: addr 0, size 16384, stride [256, 0, 262144], level: 3
#  |  |  | Out WR: addr 0, size 4096, stride [0, 4096, 32], level: 3
# **************************************************
#
# best_tiling {'B/b': (4, 4), 'OW/ow': (1, 1), 'OH/oh': (1, 1), 'IC/ic': (32, 256), 'OC/oc': (32, 32)}
# best_order ('IC/ic', 'B/b', 'OW/ow', 'OH/oh', 'OC/oc')
# Total Cycles: 262,162
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# IC/ic: Range 4, stride {'wgt': 256, 'act': 256, 'out': 0}
#  | Act RD: addr 0, size 8192, stride [256, 4096, 0], level: 1
#  | B/b: Range 4, stride {'wgt': 0, 'act': 4096, 'out': 4096}
#  |  | OC/oc: Range 32, stride {'wgt': 32768, 'act': 0, 'out': 32}
#  |  |  | Out RD: addr 0, size 4096, stride [0, 4096, 32], level: 3
#  |  |  | Wgt RD: addr 0, size 16384, stride [256, 0, 32768], level: 3
#  |  |  | Out WR: addr 0, size 4096, stride [0, 4096, 32], level: 3
# **************************************************
#
# best_tiling {'B/b': (4, 4), 'OW/ow': (1, 1), 'OH/oh': (1, 1), 'IC/ic': (4, 256), 'OC/oc': (32, 32)}
# best_order ('IC/ic', 'B/b', 'OW/ow', 'OH/oh', 'OC/oc')
# Total Cycles: 32,799
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# INFO:bitfusion.src.sweep.sweep.Simulator:Simulating Benchmark: LeNet-5
# INFO:bitfusion.src.sweep.sweep.Simulator:N x M = 16 x 32
# INFO:bitfusion.src.sweep.sweep.Simulator:Max Precision (bits): 8
# INFO:bitfusion.src.sweep.sweep.Simulator:Min Precision (bits): 8
# INFO:bitfusion.src.sweep.sweep.Simulator:Batch size: 64
# INFO:bitfusion.src.sweep.sweep.Simulator:Bandwidth (bits/cycle): 1920
# best_instructions **************************************************
# B/b: Range 16, stride {'wgt': 0, 'act': 1024, 'out': 10}
#  | Act RD: addr 0, size 2048, stride [1024], level: 1
# **************************************************
# Wgt RD: addr 0, size 65536, stride [0], level: 0
# **************************************************
# Out RD: addr 0, size 5120, stride [10], level: 0
# **************************************************
# Out WR: addr 0, size 5120, stride [10], level: 0
# **************************************************
#
# best_tiling {'B/b': (16, 1), 'OW/ow': (1, 1), 'OH/oh': (1, 1), 'IC/ic': (1, 1024), 'OC/oc': (1, 10)}
# best_order ('IC/ic', 'B/b', 'OW/ow', 'OH/oh', 'OC/oc')
# Total Cycles: 1,070
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# B/b: Range 4, stride {'wgt': 0, 'act': 5184, 'out': 131072}
#  | OW/ow: Range 32, stride {'wgt': 0, 'act': 1, 'out': 1}
#  |  | Act RD: addr 0, size 8192, stride [5184, 1, 36], level: 2
#  |  | OH/oh: Range 32, stride {'wgt': 0, 'act': 36, 'out': 32}
#  |  |  | Out RD: addr 0, size 4096, stride [131072, 1, 32], level: 3
#  |  |  | Out WR: addr 0, size 4096, stride [131072, 1, 32], level: 3
# **************************************************
# Wgt RD: addr 0, size 2048, stride [0, 0, 0], level: 0
# **************************************************
#
# best_tiling {'B/b': (4, 4), 'OW/ow': (32, 1), 'OH/oh': (32, 1), 'IC/ic': (1, 1), 'OC/oc': (1, 32)}
# best_order ('IC/ic', 'B/b', 'OW/ow', 'OH/oh', 'OC/oc')
# Total Cycles: 32,778
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# OC/oc: Range 2, stride {'wgt': 25600, 'act': 0, 'out': 8192}
#  | Wgt RD: addr 0, size 51200, stride [25600, 0, 0, 0], level: 1
#  | B/b: Range 2, stride {'wgt': 0, 'act': 102400, 'out': 131072}
#  |  | OH/oh: Range 16, stride {'wgt': 0, 'act': 20, 'out': 16}
#  |  |  | Act RD: addr 0, size 8192, stride [0, 102400, 20, 1], level: 3
#  |  |  | OW/ow: Range 16, stride {'wgt': 0, 'act': 1, 'out': 1}
#  |  |  |  | Out RD: addr 0, size 8192, stride [8192, 131072, 16, 1], level: 4
#  |  |  |  | Out WR: addr 0, size 8192, stride [8192, 131072, 16, 1], level: 4
# **************************************************
#
# best_tiling {'B/b': (2, 8), 'OW/ow': (16, 1), 'OH/oh': (16, 1), 'IC/ic': (1, 32), 'OC/oc': (2, 32)}
# best_order ('OC/oc', 'B/b', 'IC/ic', 'OH/oh', 'OW/ow')
# Total Cycles: 409,670
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# OC/oc: Range 2, stride {'wgt': 1048576, 'act': 0, 'out': 256}
#  | B/b: Range 16, stride {'wgt': 0, 'act': 4096, 'out': 512}
#  |  | Out RD: addr 0, size 8192, stride [256, 512, 0], level: 2
#  |  | Act RD: addr 0, size 8192, stride [0, 4096, 16], level: 2
#  |  | IC/ic: Range 256, stride {'wgt': 16, 'act': 16, 'out': 0}
#  |  |  | Wgt RD: addr 0, size 8192, stride [1048576, 0, 16], level: 3
#  |  | Out WR: addr 0, size 8192, stride [256, 512, 0], level: 2
# **************************************************
#
# best_tiling {'B/b': (16, 1), 'OW/ow': (1, 1), 'OH/oh': (1, 1), 'IC/ic': (256, 16), 'OC/oc': (2, 256)}
# best_order ('OC/oc', 'B/b', 'IC/ic', 'OH/oh', 'OW/ow')
# Total Cycles: 65,618
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# INFO:bitfusion.src.sweep.sweep.Simulator:Simulating Benchmark: VGG-7
# INFO:bitfusion.src.sweep.sweep.Simulator:N x M = 16 x 32
# INFO:bitfusion.src.sweep.sweep.Simulator:Max Precision (bits): 8
# INFO:bitfusion.src.sweep.sweep.Simulator:Min Precision (bits): 8
# INFO:bitfusion.src.sweep.sweep.Simulator:Batch size: 64
# INFO:bitfusion.src.sweep.sweep.Simulator:Bandwidth (bits/cycle): 1920
# best_instructions **************************************************
# B/b: Range 16, stride {'wgt': 0, 'act': 512, 'out': 10}
# **************************************************
# Wgt RD: addr 0, size 32768, stride [0], level: 0
# **************************************************
# Act RD: addr 0, size 16384, stride [512], level: 0
# **************************************************
# Out RD: addr 0, size 5120, stride [10], level: 0
# **************************************************
# Out WR: addr 0, size 5120, stride [10], level: 0
# **************************************************
#
# best_tiling {'B/b': (16, 1), 'OW/ow': (1, 1), 'OH/oh': (1, 1), 'IC/ic': (1, 512), 'OC/oc': (1, 10)}
# best_order ('IC/ic', 'B/b', 'OW/ow', 'OH/oh', 'OC/oc')
# Total Cycles: 544
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# B/b: Range 4, stride {'wgt': 0, 'act': 13872, 'out': 524288}
#  | OW/ow: Range 32, stride {'wgt': 0, 'act': 1, 'out': 1}
#  |  | Act RD: addr 0, size 4096, stride [13872, 1, 0, 34], level: 2
#  |  | OC/oc: Range 4, stride {'wgt': 864, 'act': 0, 'out': 32768}
#  |  |  | OH/oh: Range 32, stride {'wgt': 0, 'act': 34, 'out': 32}
#  |  |  |  | Out RD: addr 0, size 4096, stride [524288, 1, 32768, 32], level: 4
#  |  |  |  | Out WR: addr 0, size 4096, stride [524288, 1, 32768, 32], level: 4
# **************************************************
# Wgt RD: addr 0, size 8192, stride [0, 0, 864, 0], level: 0
# **************************************************
#
# best_tiling {'B/b': (4, 4), 'OW/ow': (32, 1), 'OH/oh': (32, 1), 'IC/ic': (1, 3), 'OC/oc': (4, 32)}
# best_order ('B/b', 'OW/ow', 'IC/ic', 'OC/oc', 'OH/oh')
# Total Cycles: 131,085
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# B/b: Range 4, stride {'wgt': 0, 'act': 13872, 'out': 524288}
#  | OW/ow: Range 32, stride {'wgt': 0, 'act': 1, 'out': 1}
#  |  | Act RD: addr 0, size 4096, stride [13872, 1, 0, 34], level: 2
#  |  | OC/oc: Range 4, stride {'wgt': 864, 'act': 0, 'out': 32768}
#  |  |  | OH/oh: Range 32, stride {'wgt': 0, 'act': 34, 'out': 32}
#  |  |  |  | Out RD: addr 0, size 4096, stride [524288, 1, 32768, 32], level: 4
#  |  |  |  | Out WR: addr 0, size 4096, stride [524288, 1, 32768, 32], level: 4
# **************************************************
# Wgt RD: addr 0, size 8192, stride [0, 0, 864, 0], level: 0
# **************************************************
#
# best_tiling {'B/b': (4, 4), 'OW/ow': (32, 1), 'OH/oh': (32, 1), 'IC/ic': (1, 3), 'OC/oc': (4, 32)}
# best_order ('B/b', 'OW/ow', 'IC/ic', 'OC/oc', 'OH/oh')
# Total Cycles: 131,085
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# IC/ic: Range 2, stride {'wgt': 576, 'act': 20736, 'out': 0}
#  | OC/oc: Range 8, stride {'wgt': 36864, 'act': 0, 'out': 8192}
#  |  | Wgt RD: addr 0, size 36864, stride [576, 36864, 0, 0, 0], level: 2
#  |  | OH/oh: Range 16, stride {'wgt': 0, 'act': 18, 'out': 16}
#  |  |  | Act RD: addr 0, size 8192, stride [20736, 0, 18, 331776, 1], level: 3
#  |  |  | B/b: Range 2, stride {'wgt': 0, 'act': 331776, 'out': 524288}
#  |  |  |  | OW/ow: Range 16, stride {'wgt': 0, 'act': 1, 'out': 1}
#  |  |  |  |  | Out RD: addr 0, size 8192, stride [0, 8192, 16, 524288, 1], level: 5
#  |  |  |  |  | Out WR: addr 0, size 8192, stride [0, 8192, 16, 524288, 1], level: 5
# **************************************************
#
# best_tiling {'B/b': (2, 8), 'OW/ow': (16, 1), 'OH/oh': (16, 1), 'IC/ic': (2, 64), 'OC/oc': (8, 32)}
# best_order ('IC/ic', 'OC/oc', 'OH/oh', 'B/b', 'OW/ow')
# Total Cycles: 2,359,330
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# IC/ic: Range 2, stride {'wgt': 576, 'act': 20736, 'out': 0}
#  | OC/oc: Range 8, stride {'wgt': 36864, 'act': 0, 'out': 8192}
#  |  | Wgt RD: addr 0, size 36864, stride [576, 36864, 0, 0, 0], level: 2
#  |  | OH/oh: Range 16, stride {'wgt': 0, 'act': 18, 'out': 16}
#  |  |  | Act RD: addr 0, size 8192, stride [20736, 0, 18, 331776, 1], level: 3
#  |  |  | B/b: Range 2, stride {'wgt': 0, 'act': 331776, 'out': 524288}
#  |  |  |  | OW/ow: Range 16, stride {'wgt': 0, 'act': 1, 'out': 1}
#  |  |  |  |  | Out RD: addr 0, size 8192, stride [0, 8192, 16, 524288, 1], level: 5
#  |  |  |  |  | Out WR: addr 0, size 8192, stride [0, 8192, 16, 524288, 1], level: 5
# **************************************************
#
# best_tiling {'B/b': (2, 8), 'OW/ow': (16, 1), 'OH/oh': (16, 1), 'IC/ic': (2, 64), 'OC/oc': (8, 32)}
# best_order ('IC/ic', 'OC/oc', 'OH/oh', 'B/b', 'OW/ow')
# Total Cycles: 2,359,330
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# IC/ic: Range 8, stride {'wgt': 288, 'act': 3200, 'out': 0}
#  | OH/oh: Range 4, stride {'wgt': 0, 'act': 10, 'out': 8}
#  |  | Act RD: addr 0, size 8192, stride [3200, 10, 51200, 2, 0], level: 2
#  |  | B/b: Range 8, stride {'wgt': 0, 'act': 51200, 'out': 65536}
#  |  |  | OW/ow: Range 4, stride {'wgt': 0, 'act': 2, 'out': 2}
#  |  |  |  | OC/oc: Range 16, stride {'wgt': 73728, 'act': 0, 'out': 2048}
#  |  |  |  |  | Out RD: addr 0, size 8192, stride [0, 8, 65536, 2, 2048], level: 5
#  |  |  |  |  | Wgt RD: addr 0, size 18432, stride [288, 0, 0, 0, 73728], level: 5
#  |  |  |  |  | Out WR: addr 0, size 8192, stride [0, 8, 65536, 2, 2048], level: 5
# **************************************************
#
# best_tiling {'B/b': (8, 2), 'OW/ow': (4, 2), 'OH/oh': (4, 2), 'IC/ic': (8, 32), 'OC/oc': (16, 32)}
# best_order ('IC/ic', 'OH/oh', 'B/b', 'OW/ow', 'OC/oc')
# Total Cycles: 2,359,325
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# IC/ic: Range 8, stride {'wgt': 288, 'act': 3200, 'out': 0}
#  | OH/oh: Range 4, stride {'wgt': 0, 'act': 10, 'out': 8}
#  |  | Act RD: addr 0, size 8192, stride [3200, 10, 51200, 2, 0], level: 2
#  |  | B/b: Range 8, stride {'wgt': 0, 'act': 51200, 'out': 65536}
#  |  |  | OW/ow: Range 4, stride {'wgt': 0, 'act': 2, 'out': 2}
#  |  |  |  | OC/oc: Range 16, stride {'wgt': 73728, 'act': 0, 'out': 2048}
#  |  |  |  |  | Out RD: addr 0, size 8192, stride [0, 8, 65536, 2, 2048], level: 5
#  |  |  |  |  | Wgt RD: addr 0, size 18432, stride [288, 0, 0, 0, 73728], level: 5
#  |  |  |  |  | Out WR: addr 0, size 8192, stride [0, 8, 65536, 2, 2048], level: 5
# **************************************************
#
# best_tiling {'B/b': (8, 2), 'OW/ow': (4, 2), 'OH/oh': (4, 2), 'IC/ic': (8, 32), 'OC/oc': (16, 32)}
# best_order ('IC/ic', 'OH/oh', 'B/b', 'OW/ow', 'OC/oc')
# Total Cycles: 2,359,325
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# INFO:bitfusion.src.sweep.sweep.Simulator:Simulating Benchmark: RESNET-18
# INFO:bitfusion.src.sweep.sweep.Simulator:N x M = 16 x 32
# INFO:bitfusion.src.sweep.sweep.Simulator:Max Precision (bits): 8
# INFO:bitfusion.src.sweep.sweep.Simulator:Min Precision (bits): 8
# INFO:bitfusion.src.sweep.sweep.Simulator:Batch size: 64
# INFO:bitfusion.src.sweep.sweep.Simulator:Bandwidth (bits/cycle): 1920
# best_instructions **************************************************
# IC/ic: Range 32, stride {'wgt': 256, 'act': 256, 'out': 0}
# ...
#  |  |  | OC/oc: Range 4, stride {'wgt': 2048, 'act': 0, 'out': 25088}
#  |  |  | Out WR: addr 0, size 4096, stride [100352, 1, 28, 25088], level: 3
# **************************************************
# Wgt RD: addr 0, size 32768, stride [0, 0, 0, 2048], level: 0
# **************************************************
#
# best_tiling {'B/b': (16, 1), 'OW/ow': (28, 1), 'OH/oh': (28, 1), 'IC/ic': (1, 64), 'OC/oc': (4, 32)}
# best_order ('IC/ic', 'B/b', 'OW/ow', 'OH/oh', 'OC/oc')
# Total Cycles: 200,730
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# OW/ow: Range 28, stride {'wgt': 0, 'act': 1, 'out': 1}
#  | B/b: Range 8, stride {'wgt': 0, 'act': 230400, 'out': 200704}
#  |  | Act RD: addr 0, size 28672, stride [1, 230400, 0, 30, 14400], level: 2
#  |  | OC/oc: Range 2, stride {'wgt': 73728, 'act': 0, 'out': 50176}
#  |  |  | OH/oh: Range 28, stride {'wgt': 0, 'act': 30, 'out': 28}
#  |  |  |  | Out RD: addr 0, size 4096, stride [1, 200704, 50176, 28, 0], level: 4
#  |  |  |  | IC/ic: Range 8, stride {'wgt': 144, 'act': 14400, 'out': 0}
#  |  |  |  |  | Wgt RD: addr 0, size 36864, stride [0, 0, 73728, 0, 144], level: 5
#  |  |  |  | Out WR: addr 0, size 4096, stride [1, 200704, 50176, 28, 0], level: 4
# **************************************************
#
# best_tiling {'B/b': (8, 2), 'OW/ow': (28, 1), 'OH/oh': (28, 1), 'IC/ic': (8, 16), 'OC/oc': (2, 64)}
# best_order ('OW/ow', 'B/b', 'OC/oc', 'OH/oh', 'IC/ic')
# Total Cycles: 3,612,702
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# IC/ic: Range 2, stride {'wgt': 64, 'act': 50176, 'out': 0}
#  | Wgt RD: addr 0, size 32768, stride [64, 0, 0, 0, 4096], level: 1
#  | B/b: Range 16, stride {'wgt': 0, 'act': 100352, 'out': 100352}
#  |  | OW/ow: Range 28, stride {'wgt': 0, 'act': 1, 'out': 1}
#  |  |  | Act RD: addr 0, size 1792, stride [50176, 100352, 1, 28, 0], level: 3
#  |  |  | OH/oh: Range 28, stride {'wgt': 0, 'act': 28, 'out': 28}
#  |  |  |  | Out RD: addr 0, size 4096, stride [0, 100352, 1, 28, 25088], level: 4
#  |  |  |  | OC/oc: Range 4, stride {'wgt': 4096, 'act': 0, 'out': 25088}
#  |  |  |  | Out WR: addr 0, size 4096, stride [0, 100352, 1, 28, 25088], level: 4
# **************************************************
#
# best_tiling {'B/b': (16, 1), 'OW/ow': (28, 1), 'OH/oh': (28, 1), 'IC/ic': (2, 64), 'OC/oc': (4, 32)}
# best_order ('IC/ic', 'B/b', 'OW/ow', 'OH/oh', 'OC/oc')
# Total Cycles: 401,451
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# OW/ow: Range 28, stride {'wgt': 0, 'act': 1, 'out': 1}
#  | B/b: Range 8, stride {'wgt': 0, 'act': 230400, 'out': 200704}
#  |  | Act RD: addr 0, size 28672, stride [1, 230400, 0, 30, 14400], level: 2
#  |  | OC/oc: Range 2, stride {'wgt': 73728, 'act': 0, 'out': 50176}
#  |  |  | OH/oh: Range 28, stride {'wgt': 0, 'act': 30, 'out': 28}
#  |  |  |  | Out RD: addr 0, size 4096, stride [1, 200704, 50176, 28, 0], level: 4
#  |  |  |  | IC/ic: Range 8, stride {'wgt': 144, 'act': 14400, 'out': 0}
#  |  |  |  |  | Wgt RD: addr 0, size 36864, stride [0, 0, 73728, 0, 144], level: 5
#  |  |  |  | Out WR: addr 0, size 4096, stride [1, 200704, 50176, 28, 0], level: 4
# **************************************************
#
# best_tiling {'B/b': (8, 2), 'OW/ow': (28, 1), 'OH/oh': (28, 1), 'IC/ic': (8, 16), 'OC/oc': (2, 64)}
# best_order ('OW/ow', 'B/b', 'OC/oc', 'OH/oh', 'IC/ic')
# Total Cycles: 3,612,702
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# B/b: Range 8, stride {'wgt': 0, 'act': 186624, 'out': 100352}
#  | Act RD: addr 0, size 25088, stride [186624, 2, 0, 54], level: 1
#  | OW/ow: Range 14, stride {'wgt': 0, 'act': 2, 'out': 1}
#  |  | OC/oc: Range 2, stride {'wgt': 16384, 'act': 0, 'out': 25088}
#  |  |  | Wgt RD: addr 0, size 65536, stride [0, 0, 16384, 0], level: 3
#  |  |  | OH/oh: Range 14, stride {'wgt': 0, 'act': 54, 'out': 14}
#  |  |  |  | Out RD: addr 0, size 8192, stride [100352, 1, 25088, 14], level: 4
#  |  |  |  | Out WR: addr 0, size 8192, stride [100352, 1, 25088, 14], level: 4
# **************************************************
#
# best_tiling {'B/b': (8, 2), 'OW/ow': (14, 1), 'OH/oh': (14, 1), 'IC/ic': (1, 128), 'OC/oc': (2, 128)}
# best_order ('B/b', 'OW/ow', 'IC/ic', 'OC/oc', 'OH/oh')
# Total Cycles: 200,789
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# OW/ow: Range 7, stride {'wgt': 0, 'act': 2, 'out': 2}
#  | OH/oh: Range 7, stride {'wgt': 0, 'act': 16, 'out': 14}
#  |  | B/b: Range 4, stride {'wgt': 0, 'act': 262144, 'out': 200704}
#  |  |  | Act RD: addr 0, size 16384, stride [2, 16, 262144, 0, 4096], level: 3
#  |  |  | OC/oc: Range 8, stride {'wgt': 73728, 'act': 0, 'out': 6272}
#  |  |  |  | Out RD: addr 0, size 16384, stride [2, 14, 200704, 6272, 0], level: 4
#  |  |  |  | IC/ic: Range 16, stride {'wgt': 144, 'act': 4096, 'out': 0}
#  |  |  |  |  | Wgt RD: addr 0, size 18432, stride [0, 0, 0, 73728, 144], level: 5
#  |  |  |  | Out WR: addr 0, size 16384, stride [2, 14, 200704, 6272, 0], level: 4
# **************************************************
#
# best_tiling {'B/b': (4, 4), 'OW/ow': (7, 2), 'OH/oh': (7, 2), 'IC/ic': (16, 16), 'OC/oc': (8, 32)}
# best_order ('OW/ow', 'OH/oh', 'B/b', 'OC/oc', 'IC/ic')
# Total Cycles: 3,612,704
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# B/b: Range 16, stride {'wgt': 0, 'act': 50176, 'out': 50176}
#  | Act RD: addr 0, size 12544, stride [50176, 1, 14, 0], level: 1
#  | OW/ow: Range 14, stride {'wgt': 0, 'act': 1, 'out': 1}
#  |  | OH/oh: Range 14, stride {'wgt': 0, 'act': 14, 'out': 14}
#  |  |  | Out RD: addr 0, size 8192, stride [50176, 1, 14, 6272], level: 3
#  |  |  | OC/oc: Range 8, stride {'wgt': 8192, 'act': 0, 'out': 6272}
#  |  |  |  | Wgt RD: addr 0, size 32768, stride [0, 0, 0, 8192], level: 4
#  |  |  | Out WR: addr 0, size 8192, stride [50176, 1, 14, 6272], level: 3
# **************************************************
#
# best_tiling {'B/b': (16, 1), 'OW/ow': (14, 1), 'OH/oh': (14, 1), 'IC/ic': (1, 256), 'OC/oc': (8, 32)}
# best_order ('IC/ic', 'B/b', 'OW/ow', 'OH/oh', 'OC/oc')
# Total Cycles: 401,562
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# OW/ow: Range 7, stride {'wgt': 0, 'act': 2, 'out': 2}
#  | OH/oh: Range 7, stride {'wgt': 0, 'act': 16, 'out': 14}
#  |  | B/b: Range 4, stride {'wgt': 0, 'act': 262144, 'out': 200704}
#  |  |  | Act RD: addr 0, size 16384, stride [2, 16, 262144, 0, 4096], level: 3
#  |  |  | OC/oc: Range 8, stride {'wgt': 73728, 'act': 0, 'out': 6272}
#  |  |  |  | Out RD: addr 0, size 16384, stride [2, 14, 200704, 6272, 0], level: 4
#  |  |  |  | IC/ic: Range 16, stride {'wgt': 144, 'act': 4096, 'out': 0}
#  |  |  |  |  | Wgt RD: addr 0, size 18432, stride [0, 0, 0, 73728, 144], level: 5
#  |  |  |  | Out WR: addr 0, size 16384, stride [2, 14, 200704, 6272, 0], level: 4
# **************************************************
#
# best_tiling {'B/b': (4, 4), 'OW/ow': (7, 2), 'OH/oh': (7, 2), 'IC/ic': (16, 16), 'OC/oc': (8, 32)}
# best_order ('OW/ow', 'OH/oh', 'B/b', 'OC/oc', 'IC/ic')
# Total Cycles: 3,612,704
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# OC/oc: Range 16, stride {'wgt': 8192, 'act': 0, 'out': 1568}
#  | Wgt RD: addr 0, size 32768, stride [8192, 64, 0, 0, 0], level: 1
#  | IC/ic: Range 4, stride {'wgt': 64, 'act': 10816, 'out': 0}
#  |  | OW/ow: Range 7, stride {'wgt': 0, 'act': 2, 'out': 1}
#  |  |  | Act RD: addr 0, size 7168, stride [0, 10816, 2, 43264, 26], level: 3
#  |  |  | B/b: Range 16, stride {'wgt': 0, 'act': 43264, 'out': 25088}
#  |  |  |  | Out RD: addr 0, size 7168, stride [1568, 0, 1, 25088, 7], level: 4
#  |  |  |  | OH/oh: Range 7, stride {'wgt': 0, 'act': 26, 'out': 7}
#  |  |  |  | Out WR: addr 0, size 7168, stride [1568, 0, 1, 25088, 7], level: 4
# **************************************************
#
# best_tiling {'B/b': (16, 1), 'OW/ow': (7, 1), 'OH/oh': (7, 1), 'IC/ic': (4, 64), 'OC/oc': (16, 32)}
# best_order ('OC/oc', 'IC/ic', 'OW/ow', 'B/b', 'OH/oh')
# Total Cycles: 200,744
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# OW/ow: Range 7, stride {'wgt': 0, 'act': 1, 'out': 1}
#  | OH/oh: Range 7, stride {'wgt': 0, 'act': 9, 'out': 7}
#  |  | B/b: Range 2, stride {'wgt': 0, 'act': 331776, 'out': 200704}
#  |  |  | Act RD: addr 0, size 16384, stride [1, 9, 331776, 0, 1296], level: 3
#  |  |  | OC/oc: Range 16, stride {'wgt': 147456, 'act': 0, 'out': 1568}
#  |  |  |  | Out RD: addr 0, size 8192, stride [1, 7, 200704, 1568, 0], level: 4
#  |  |  |  | IC/ic: Range 32, stride {'wgt': 144, 'act': 1296, 'out': 0}
#  |  |  |  |  | Wgt RD: addr 0, size 18432, stride [0, 0, 0, 147456, 144], level: 5
#  |  |  |  | Out WR: addr 0, size 8192, stride [1, 7, 200704, 1568, 0], level: 4
# **************************************************
#
# best_tiling {'B/b': (2, 8), 'OW/ow': (7, 1), 'OH/oh': (7, 1), 'IC/ic': (32, 16), 'OC/oc': (16, 32)}
# best_order ('OW/ow', 'OH/oh', 'B/b', 'OC/oc', 'IC/ic')
# Total Cycles: 3,612,694
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# OW/ow: Range 7, stride {'wgt': 0, 'act': 1, 'out': 1}
#  | Act RD: addr 0, size 14336, stride [1, 25088, 12544, 0, 7], level: 1
#  | B/b: Range 16, stride {'wgt': 0, 'act': 25088, 'out': 25088}
#  |  | IC/ic: Range 2, stride {'wgt': 256, 'act': 12544, 'out': 0}
#  |  |  | OC/oc: Range 16, stride {'wgt': 16384, 'act': 0, 'out': 1568}
#  |  |  |  | Out RD: addr 0, size 7168, stride [1, 25088, 0, 1568, 7], level: 4
#  |  |  |  | Wgt RD: addr 0, size 32768, stride [0, 0, 256, 16384, 0], level: 4
#  |  |  |  | OH/oh: Range 7, stride {'wgt': 0, 'act': 7, 'out': 7}
#  |  |  |  | Out WR: addr 0, size 7168, stride [1, 25088, 0, 1568, 7], level: 4
# **************************************************
#
# best_tiling {'B/b': (16, 1), 'OW/ow': (7, 1), 'OH/oh': (7, 1), 'IC/ic': (2, 256), 'OC/oc': (16, 32)}
# best_order ('OW/ow', 'B/b', 'IC/ic', 'OC/oc', 'OH/oh')
# Total Cycles: 401,441
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# INFO:bitfusion.src.sweep.sweep.Simulator:Simulating Benchmark: RNN
# INFO:bitfusion.src.sweep.sweep.Simulator:N x M = 16 x 32
# INFO:bitfusion.src.sweep.sweep.Simulator:Max Precision (bits): 8
# INFO:bitfusion.src.sweep.sweep.Simulator:Min Precision (bits): 8
# INFO:bitfusion.src.sweep.sweep.Simulator:Batch size: 64
# INFO:bitfusion.src.sweep.sweep.Simulator:Bandwidth (bits/cycle): 1920
# best_instructions **************************************************
# OW/ow: Range 7, stride {'wgt': 0, 'act': 1, 'out': 1}
#  | OH/oh: Range 7, stride {'wgt': 0, 'act': 9, 'out': 7}
#  |  | B/b: Range 2, stride {'wgt': 0, 'act': 331776, 'out': 200704}
#  |  |  | Act RD: addr 0, size 16384, stride [1, 9, 331776, 0, 1296], level: 3
#  |  |  | OC/oc: Range 16, stride {'wgt': 147456, 'act': 0, 'out': 1568}
#  |  |  |  | Out RD: addr 0, size 8192, stride [1, 7, 200704, 1568, 0], level: 4
#  |  |  |  | IC/ic: Range 32, stride {'wgt': 144, 'act': 1296, 'out': 0}
#  |  |  |  |  | Wgt RD: addr 0, size 18432, stride [0, 0, 0, 147456, 144], level: 5
#  |  |  |  | Out WR: addr 0, size 8192, stride [1, 7, 200704, 1568, 0], level: 4
# **************************************************
#
# best_tiling {'B/b': (2, 8), 'OW/ow': (7, 1), 'OH/oh': (7, 1), 'IC/ic': (32, 16), 'OC/oc': (16, 32)}
# best_order ('OW/ow', 'OH/oh', 'B/b', 'OC/oc', 'IC/ic')
# Total Cycles: 3,612,694
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# INFO:bitfusion.src.sweep.sweep.Simulator:Simulating Benchmark: LSTM
# INFO:bitfusion.src.sweep.sweep.Simulator:N x M = 16 x 32
# INFO:bitfusion.src.sweep.sweep.Simulator:Max Precision (bits): 8
# INFO:bitfusion.src.sweep.sweep.Simulator:Min Precision (bits): 8
# INFO:bitfusion.src.sweep.sweep.Simulator:Batch size: 64
# INFO:bitfusion.src.sweep.sweep.Simulator:Bandwidth (bits/cycle): 1920
# best_instructions **************************************************
# IC/ic: Range 128, stride {'wgt': 32, 'act': 32, 'out': 0}
#  | Act RD: addr 0, size 2048, stride [32, 16384, 0], level: 1
#  | B/b: Range 4, stride {'wgt': 0, 'act': 16384, 'out': 16384}
#  |  | OC/oc: Range 128, stride {'wgt': 131072, 'act': 0, 'out': 32}
#  |  |  | Out RD: addr 0, size 4096, stride [0, 16384, 32], level: 3
#  |  |  | Wgt RD: addr 0, size 4096, stride [32, 0, 131072], level: 3
#  |  |  | Out WR: addr 0, size 4096, stride [0, 16384, 32], level: 3
# **************************************************
#
# best_tiling {'B/b': (4, 4), 'OW/ow': (1, 1), 'OH/oh': (1, 1), 'IC/ic': (128, 32), 'OC/oc': (128, 32)}
# best_order ('IC/ic', 'B/b', 'OW/ow', 'OH/oh', 'OC/oc')
# Total Cycles: 524,297
# {'size (bytes)': 128.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# cfg_dict {'size (bytes)': 2048.0, 'block size (bytes)': 4.0, 'read-write port': 0}
# 0
# lookup_dict {'Max Precision (bits)': 8, 'Min Precision (bits)': 8, 'N': 4, 'M': 4}
# best_instructions **************************************************
# OC/oc: Range 113, stride {'wgt': 115200, 'act': 0, 'out': 32}
#  | Out RD: addr 0, size 16384, stride [32, 0], level: 1
#  | IC/ic: Range 225, stride {'wgt': 16, 'act': 16, 'out': 0}
#  |  | Act RD: addr 0, size 1024, stride [0, 16], level: 2
#  |  | Wgt RD: addr 0, size 2048, stride [115200, 16], level: 2
#  | Out WR: addr 0, size 16384, stride [32, 0], level: 1
# **************************************************
#
# best_tiling {'B/b': (1, 16), 'OW/ow': (1, 1), 'OH/oh': (1, 1), 'IC/ic': (225, 16), 'OC/oc': (113, 32)}
# best_order ('OC/oc', 'B/b', 'IC/ic', 'OH/oh', 'OW/ow')
# Total Cycles: 406,820

# %% [markdown]
# ### Get Eyeriss numbers

# %%
def get_eyeriss_energy(df):

    eyeriss_energy_per_mac = 16 * 0.2 * 1.e-3 #energy in nJ
    # python2 弊病
    # eyeriss_energy_alu = float(df['ALU'])
    # eyeriss_energy_dram = float(df['DRAM']) * 0.15 #Scaling due to technology
    # eyeriss_energy_buffer = float(df['Buffer'])
    # eyeriss_energy_array = float(df['Array'])
    # eyeriss_energy_rf = float(df['RF'])

    eyeriss_energy_alu = pandas.to_numeric(df['ALU'],errors='coerce').astype(float).item()
    eyeriss_energy_dram = pandas.to_numeric(df['DRAM'],errors='coerce').astype(float).item() * 0.15 #Scaling due to technology
    eyeriss_energy_buffer = pandas.to_numeric(df['Buffer'],errors='coerce').astype(float).item()
    eyeriss_energy_array = pandas.to_numeric(df['Array'],errors='coerce').astype(float).item()
    eyeriss_energy_rf = pandas.to_numeric(df['RF'],errors='coerce').astype(float).item()


    eyeriss_energy = eyeriss_energy_alu + eyeriss_energy_dram + eyeriss_energy_buffer + eyeriss_energy_array + eyeriss_energy_rf
    eyeriss_energy *= eyeriss_energy_per_mac
    return eyeriss_energy

def get_eyeriss_energy_breakdown(df):
    eyeriss_energy_per_mac = 16 * 0.2 * 1.e-3 #energy in nJ
    
    # eyeriss_energy_alu = float(df['ALU'])
    # eyeriss_energy_dram = float(df['DRAM'])
    # eyeriss_energy_buffer = float(df['Buffer'])
    # eyeriss_energy_array = float(df['Array'])
    # eyeriss_energy_rf = float(df['RF'])

    eyeriss_energy_alu = pandas.to_numeric(df['ALU'],errors='coerce').astype(float).item()
    eyeriss_energy_dram = pandas.to_numeric(df['DRAM'],errors='coerce').astype(float).item()
    eyeriss_energy_buffer = pandas.to_numeric(df['Buffer'],errors='coerce').astype(float).item()
    eyeriss_energy_array = pandas.to_numeric(df['Array'],errors='coerce').astype(float).item()
    eyeriss_energy_rf = pandas.to_numeric(df['RF'],errors='coerce').astype(float).item()




    eyeriss_energy = [eyeriss_energy_alu+eyeriss_energy_array, eyeriss_energy_buffer, eyeriss_energy_rf, eyeriss_energy_dram]
    eyeriss_energy = [x * eyeriss_energy_per_mac for x in eyeriss_energy]
    return eyeriss_energy

def df_to_stats(df):
    stats = Stats()
    # stats.total_cycles = float(df['Cycles'])
    # stats.mem_stall_cycles = float(df['Memory wait cycles'])
    # stats.reads['act'] = float(df['IBUF Read'])
    # stats.reads['out'] = float(df['OBUF Read'])
    # stats.reads['wgt'] = float(df['WBUF Read'])
    # stats.reads['dram'] = float(df['DRAM Read'])
    # stats.writes['act'] = float(df['IBUF Write'])
    # stats.writes['out'] = float(df['OBUF Write'])
    # stats.writes['wgt'] = float(df['WBUF Write'])
    # stats.writes['dram'] = float(df['DRAM Write'])

    stats.total_cycles = pandas.to_numeric(df['Cycles'],errors='coerce').astype(float).item()
    stats.mem_stall_cycles = pandas.to_numeric(df['Memory wait cycles'],errors='coerce').astype(float).item()
    stats.reads['act'] = pandas.to_numeric(df['IBUF Read'],errors='coerce').astype(float).item()
    stats.reads['out'] = pandas.to_numeric(df['OBUF Read'],errors='coerce').astype(float).item()
    stats.reads['wgt'] = pandas.to_numeric(df['WBUF Read'],errors='coerce').astype(float).item()
    stats.reads['dram'] = pandas.to_numeric(df['DRAM Read'],errors='coerce').astype(float).item()
    stats.writes['act'] = pandas.to_numeric(df['IBUF Write'],errors='coerce').astype(float).item()
    stats.writes['out'] = pandas.to_numeric(df['OBUF Write'],errors='coerce').astype(float).item()
    stats.writes['wgt'] = pandas.to_numeric(df['WBUF Write'],errors='coerce').astype(float).item()
    stats.writes['dram'] = pandas.to_numeric(df['DRAM Write'],errors='coerce').astype(float).item()




    return stats

# %%
# Eyeriss-Simulator
# 这个测试的csv得换
# eyeriss_results.csv 给出了具体某一个网络某一层的
# ALU DRAM Buffer Array RF time(ms)
# 横向对比模块
eyeriss_data = pandas.read_csv(os.path.join(results_dir, 'eyeriss_results.csv'))

eyeriss_data_bench = eyeriss_data.groupby('Benchmark', as_index=False).agg(np.sum)

eyeriss_data_bench['Platform'] = 'Eyeriss (16-bit)'
print(eyeriss_data_bench)

# bench='AlexNet'
# lookup_dict = {'Benchmark': bench}
# eyeriss_cycles = lookup_pandas_dataframe(eyeriss_data_bench, lookup_dict)['time(ms)'].astype(float)[0]

# print(eyeriss_cycles[0])

# %%
print('BitFusion-Eyeriss comparison')
eyeriss_area = 3.5*3.5*45*45/65./65.
print('Area budget = {}'.format(eyeriss_area))


print(area_stats)
if abs(sum(area_stats)-eyeriss_area)/eyeriss_area > 0.1:
    print('Warning: BitFusion Area is outside 10% of eyeriss')
print('total_area = {}, budget = {}'.format(sum(area_stats), eyeriss_area))
bf_e_area = sum(area_stats)

baseline_data = []

# 由于上述csv数据没有benchmarks的数据，所以用test代替
# 得找到适配benchmack的数据再跑一遍
# test = ['AlexNet','LSTM']

for bench in benchmarks.benchlist:

# for bench in test:
    print('bench:',bench)
    lookup_dict = {'Benchmark': bench}

    # eyeriss_cycles = float(lookup_pandas_dataframe(eyeriss_data_bench, lookup_dict)['time(ms)'])
    eyeriss_cycles = lookup_pandas_dataframe(eyeriss_data_bench, lookup_dict)['time(ms)'].astype(float).item()
    
    print('eyeriss_cycles',eyeriss_cycles)

    eyeriss_time = eyeriss_cycles / 500.e3 / 16


    eyeriss_energy = get_eyeriss_energy(lookup_pandas_dataframe(eyeriss_data_bench, lookup_dict))
    eyeriss_power = eyeriss_energy / eyeriss_time * 1.e-9

    eyeriss_speedup = eyeriss_time / eyeriss_time
    eyeriss_energy_efficiency = eyeriss_energy / eyeriss_energy

    eyeriss_ppa = eyeriss_speedup / eyeriss_area / (eyeriss_speedup / eyeriss_area)
    eyeriss_ppw = eyeriss_speedup / eyeriss_power / (eyeriss_speedup / eyeriss_power)
    
    bf_e_stats = df_to_stats(bf_e_results.loc[bf_e_results['Network'] == bench])


    print('bbc',bf_e_stats.total_cycles)
    bf_e_cycles = bf_e_stats.total_cycles * (batch_size / 16.)

    bf_e_time = bf_e_cycles / 500.e3 / 16

    bf_e_energy = bf_e_stats.get_energy(bf_e_sim.get_energy_cost()) * (batch_size / 16.)
    bf_e_power = bf_e_energy / bf_e_time * 1.e-9

    bf_e_speedup = eyeriss_time / bf_e_time

    bf_e_energy_efficiency = eyeriss_energy / bf_e_energy

    bf_e_ppa = bf_e_speedup / bf_e_area / (eyeriss_speedup / eyeriss_area)
    bf_e_ppw = bf_e_speedup / bf_e_power / (eyeriss_speedup / eyeriss_power)

    baseline_data.append(['Performance', bench, bf_e_speedup])
    baseline_data.append(['Energy reduction', bench, bf_e_energy_efficiency])
    baseline_data.append(['Performance-per-Watt', bench, bf_e_ppw])
    baseline_data.append(['Performance-per-Area', bench, bf_e_ppa])
    
    print('*'*50)
    print('Benchmark: {}'.format(bench))
    
    # 二者在时间上对比
    print('Eyeriss time: {} ms'.format(eyeriss_time))
    print('BitFusion time: {} ms'.format(bf_e_time))
   
    # 二者在能耗上对比
    print('Eyeriss power: {} mWatt'.format(eyeriss_power*1.e3*16))
    print('BitFusion power: {} mWatt'.format(bf_e_power*1.e3*16))
    print('*'*50)
    
eyeriss_comparison_df = pandas.DataFrame(baseline_data, columns=['Metric', 'Network', 'Value'])

# %%
print(eyeriss_data_bench)
eyeriss_data_bench['Platform'] = 'Eyeriss (16-bit)'



print('BitFusion-Eyeriss comparison')
eyeriss_area = 3.5*3.5*45*45/65./65.
print('Area budget = {}'.format(eyeriss_area))


print(area_stats)
if abs(sum(area_stats)-eyeriss_area)/eyeriss_area > 0.1:
    print('Warning: BitFusion Area is outside 10% of eyeriss')
print('total_area = {}, budget = {}'.format(sum(area_stats), eyeriss_area))
bf_e_area = sum(area_stats)

baseline_data = []
for bench in benchmarks.benchlist:

    lookup_dict = {'Benchmark': bench}

    # eyeriss_cycles = float(lookup_pandas_dataframe(eyeriss_data_bench, lookup_dict)['time(ms)'])
    eyeriss_cycles = lookup_pandas_dataframe(eyeriss_data_bench, lookup_dict)['time(ms)'].astype(float).item()
    
    # print('eyeriss_cycles',eyeriss_cycles)

    eyeriss_time = eyeriss_cycles / 500.e3 / 16


    eyeriss_energy = get_eyeriss_energy(lookup_pandas_dataframe(eyeriss_data_bench, lookup_dict))
    eyeriss_power = eyeriss_energy / eyeriss_time * 1.e-9

    eyeriss_speedup = eyeriss_time / eyeriss_time
    eyeriss_energy_efficiency = eyeriss_energy / eyeriss_energy

    eyeriss_ppa = eyeriss_speedup / eyeriss_area / (eyeriss_speedup / eyeriss_area)
    eyeriss_ppw = eyeriss_speedup / eyeriss_power / (eyeriss_speedup / eyeriss_power)
    
    bf_e_stats = df_to_stats(bf_e_results.loc[bf_e_results['Network'] == bench])
    bf_e_cycles = bf_e_stats.total_cycles * (batch_size / 16.)
    bf_e_time = bf_e_cycles / 500.e3 / 16
    bf_e_energy = bf_e_stats.get_energy(bf_e_sim.get_energy_cost()) * (batch_size / 16.)
    bf_e_power = bf_e_energy / bf_e_time * 1.e-9

    bf_e_speedup = eyeriss_time / bf_e_time
    bf_e_energy_efficiency = eyeriss_energy / bf_e_energy

    bf_e_ppa = bf_e_speedup / bf_e_area / (eyeriss_speedup / eyeriss_area)
    bf_e_ppw = bf_e_speedup / bf_e_power / (eyeriss_speedup / eyeriss_power)

    baseline_data.append(['Performance', bench, bf_e_speedup])
    baseline_data.append(['Energy reduction', bench, bf_e_energy_efficiency])
    baseline_data.append(['Performance-per-Watt', bench, bf_e_ppw])
    baseline_data.append(['Performance-per-Area', bench, bf_e_ppa])
    
    print('*'*50)
    print('Benchmark: {}'.format(bench))

    print('Eyeriss time: {} ms'.format(eyeriss_time))

    print('BitFusion time: {} ms'.format(bf_e_time))    
    print('Eyeriss power: {} mWatt'.format(eyeriss_power*1.e3*16))
    print('BitFusion power: {} mWatt'.format(bf_e_power*1.e3*16))
    print('*'*50)
    
eyeriss_comparison_df = pandas.DataFrame(baseline_data, columns=['Metric', 'Network', 'Value'])

# %%
# latex 安装 https://blog.csdn.net/Baby_of_breath/article/details/125667000
bc = BarChart()
bc.LABEL_BAR = True
bc.BAR_WIDTH = None
bc.YAXIS_MAX = 16
bc.ISTIMES = True
bc.TOP_ROTATE = True
bc.LEGEND_LOCATION = "upper center"
bc.LEGEND_NCOLUMN = 5
bc.MV_LEGEND_OUTSIDE_Y = 1.4
bc.MV_LEGEND_OUTSIDE_X = 0.5
bc.LOG_SCALE = False
bc.FIG_WIDTH = 16
bc.TOP_LABEL_FONTSIZE = 12
bc.LEGEND_FONTSIZE = 16

print(eyeriss_comparison_df)
# print(eyeriss_comparison_df)
print(type(eyeriss_comparison_df))


#画图有问题，暂时存成csv
# eyeriss_comparison_df.to_csv('./table/eyeriss-comparision.csv', index=True)


print('Generating Figure for GPU performance comparison')

bc.yaxis = 'Performance-over-Eyeriss'
bc.BAR_WIDTH = None
legend_list = ['Performance', 'Energy reduction']

fig_name = os.path.join(fig_dir, 'eyeriss-comparision.pdf')

# print('h',fig_name)

bc.plot(fig_name, eyeriss_comparison_df, x_plot='Network', y_plot='Value', bar_plot='Metric',
        bar_list=legend_list, add_geomean=True)

# %% [markdown]
# ### Energy breakdown for Eyeriss and BitFusion

# %%
breakdown_data = []
for bench in benchmarks.benchlist:
    lookup_dict = {'Benchmark': bench}
    eyeriss_energy = get_eyeriss_energy_breakdown(lookup_pandas_dataframe(eyeriss_data_bench, lookup_dict))
    total_energy = sum(eyeriss_energy)
    eyeriss_breakdown = [x / float(total_energy) for x in eyeriss_energy]
    
    breakdown_data.append(['Eyeriss', bench] + eyeriss_breakdown)
    
    bf_e_stats = df_to_stats(bf_e_results.loc[bf_e_results['Network'] == bench])
    bf_breakdown = bf_e_stats.get_energy_breakdown(bf_e_sim.get_energy_cost())
    total = sum(bf_breakdown)
    bf_breakdown = [x / float(total) for x in bf_breakdown]
    
    breakdown_data.append(['BitFusion', bench] + bf_breakdown)
    
breakdown_df = pandas.DataFrame(breakdown_data, columns = ['Platform', 'Network', 'Compute', 'Register File', 'Buffers', 'DRAM'])

# %%
bc = BarChart()
bc.LABEL_BAR = False
bc.BAR_LEFT_MARGIN = 1
bc.BAR_GAP = 0.1
bc.YAXIS_MAX = 1
bc.ISTIMES = True
bc.TOP_ROTATE = True
bc.LEGEND_LOCATION = "upper center"
bc.LEGEND_NCOLUMN = 5
bc.MV_LEGEND_OUTSIDE_Y = 1.2
bc.MV_LEGEND_OUTSIDE_X = 0.5
bc.LOG_SCALE = False
bc.FIG_WIDTH = 16
bc.TOP_LABEL_FONTSIZE = 12
bc.LEGEND_FONTSIZE = 16

print(eyeriss_comparison_df)


# print('Generating Figure for GPU performance comparison')
bc.yaxis = 'Energy breakdown'
bc.BAR_WIDTH = None
legend_list = ['Eyeriss', 'BitFusion']
fig_name = os.path.join(fig_dir, 'bitfusion-eyeriss-energy-breakdown.pdf')
bc.plot(fig_name, breakdown_df, x_plot='Network', y_plot=['Compute', 'Register File', 'Buffers', 'DRAM'], bar_plot='Platform',
        bar_list=legend_list)

# %% [markdown]
# ## GPU numbers

# %%
gpu_data = []
gpu_list = ['TX2-fp32', 'TitanX-fp32', 'TitanX-int8']
config = ConfigParser.ConfigParser()
config.read('results/output.ini')
for bench in benchmarks.benchlist:
    # Titan-X Pascal numbers
    titanx_fp32_sec = '{}-performance-batch-{}'.format('TitanX-fp32', batch_size)    
    titanx_int8_sec = '{}-performance-batch-{}'.format('TitanX-int8', batch_size)
    titanx_fp32_time = config.getfloat(titanx_fp32_sec, bench.lower())
    titanx_int8_time = config.getfloat(titanx_int8_sec, bench.lower())    
    titanx_fp32_fps = batch_size / titanx_fp32_time * 1.e3
    titanx_int8_fps = batch_size / titanx_int8_time * 1.e3
    int8_speedup = titanx_int8_fps/titanx_fp32_fps
    
    gpu_data.append(['TitanX', bench, 'fp32', titanx_fp32_fps, batch_size])
    gpu_data.append(['TitanX', bench, 'int8', titanx_int8_fps, batch_size])
    
    # Jetson-TX2 numbers
    tx2_fp32_sec = '{}-performance-batch-{}'.format('TX2-fp32', batch_size)    
    tx2_int8_sec = '{}-performance-batch-{}'.format('TX2-int8', batch_size)
    tx2_fp32_time = config.getfloat(tx2_fp32_sec, bench.lower())
    try:
        tx2_int8_time = config.getfloat(tx2_int8_sec, bench.lower())
    except:
        # ID4A speedup
        tx2_int8_time = tx2_fp32_time / int8_speedup
    tx2_fp32_fps = batch_size / tx2_fp32_time * 1.e3 * 2
    tx2_int8_fps = batch_size / tx2_int8_time * 1.e3 * 2
    
    gpu_data.append(['TX2', bench, 'fp32', tx2_fp32_fps, batch_size])
    gpu_data.append(['TX2', bench, 'int8', tx2_int8_fps, batch_size])
    
#     print(v100_fp32_time, v100_int8_time)
#     print(titanx_fp32_time, titanx_int8_time)
    
gpu_data = pandas.DataFrame(gpu_data, columns=['Platform', 'Network', 'Precision', 'fps', 'Batch size'])

gpu_fps_df = gpu_data
gpu_fps_df['Name'] = gpu_fps_df['Platform'] + '-' + gpu_fps_df['Precision']
gpu_fps_df = gpu_fps_df[['Name', 'Network', 'fps', 'Batch size']]

print(gpu_fps_df)

# %% [markdown]
# ## BitFusion numbers

# %%
# Constant for a particular accelerator configuration
accelerator_constants = ['N', 'M',
                         'Max Precision (bits)', 'Min Precision (bits)',
                         'WBUF Size (bits)', 'OBUF Size (bits)', 'IBUF Size (bits)',
                         'Bandwidth (bits/cycle)'
                        ]
# Constant for a particular network run
algorithm_constants = ['Batch size']


# Variables (to be summed) for a particular network run
variable_columns = ['Cycles', 'Memory wait cycles',
                    'WBUF Read', 'WBUF Write',
                    'OBUF Read', 'OBUF Write',
                    'IBUF Read', 'IBUF Write',
                    'DRAM Read', 'DRAM Write',
                   ]

sim_sweep_columns = accelerator_constants + \
                        algorithm_constants + \
                        variable_columns + \
                        ['Network', 'Layer']


# CSV for sweeps
bf_e_sim_sweep_csv = os.path.join(results_dir, 'bitfusion-eyeriss-sim-sweep.csv')
if os.path.exists(bf_e_sim_sweep_csv):
    bf_e_sim_sweep_df = pandas.read_csv(bf_e_sim_sweep_csv)
else:
    bf_e_sim_sweep_df = pandas.DataFrame(columns=sim_sweep_columns)
# print('Got BitFusion Eyeriss Numbers')
# print(bf_e_sim_sweep_df)

bf_e_results = check_pandas_or_run(bf_e_sim, bf_e_sim_sweep_df,
                                   bf_e_sim_sweep_csv, batch_size=batch_size)
bf_e_results = bf_e_results.groupby(['Network', 'Batch size']+accelerator_constants,
                                    as_index=False).agg(np.sum)
frequency = bf_e_sim.accelerator.frequency #500 MHz
bf_e_results['Time (ms)'] = bf_e_results['Cycles'] * 1.e3 / frequency # in ms
bf_e_results['fps'] = batch_size / bf_e_results['Time (ms)'] * 1.e3


for bench in benchmarks.benchlist:
    graph = benchmarks.get_bench_nn(bench)
    bf_e_datarow = lookup_pandas_dataframe(bf_e_results, {'Network': bench})
    cycles = bf_e_datarow.Cycles
    mem_cycles = bf_e_datarow['Memory wait cycles']
            
    print('*'*50)
    print(bench)
    bf_e_fps = float(bf_e_datarow['fps'])
    print('\tAchieved FPS = {:.2f} frames/sec'.format(bf_e_fps))
    tx2_fps = float(lookup_pandas_dataframe(gpu_fps_df, {'Name': 'TX2-fp32', 'Network': bench})['fps'])
    titanx_fps = float(lookup_pandas_dataframe(gpu_fps_df, {'Name': 'TitanX-int8', 'Network': bench})['fps'])
    
    titanx_speedup = titanx_fps / tx2_fps
    bf_e_speedup = bf_e_fps / tx2_fps
    
    print('\tBitfusion speedup over TX2: {}'.format(bf_e_speedup))
    print('\tTitanX speedup over TX2: {}'.format(titanx_speedup))
    
    print('*'*50)

# %% [markdown]
# ## Generate performance comparisons

# %%
bf_e_fps_df = bf_e_results[['Network', 'fps']]
bf_e_fps_df['Name'] = 'BitFusion-45nm'

all_fps_df = pandas.concat([bf_e_fps_df, gpu_fps_df])[['Network', 'Name', 'fps']]
print(all_fps_df)
platform_list = ['TX2-fp32', 'TitanX-fp32', 'TitanX-int8', 'BitFusion-45nm']
all_fps_df = all_fps_df[all_fps_df['Name'].isin(platform_list)]
# print(all_fps_df)

# %% [markdown]
# ## GPU performance comparison figure

# %%
bc = BarChart()
bc.LABEL_BAR = True
bc.BAR_WIDTH = None
bc.YAXIS_MAX = 5
bc.ISTIMES = True
bc.TOP_ROTATE = True
bc.LEGEND_LOCATION = "upper center"
bc.LEGEND_NCOLUMN = 5
bc.MV_LEGEND_OUTSIDE_Y = 1.4
bc.MV_LEGEND_OUTSIDE_X = 0.5
bc.LOG_SCALE = False
bc.FIG_WIDTH = 16
bc.TOP_LABEL_FONTSIZE = 12
bc.LEGEND_FONTSIZE = 16

# print('Generating Figure for GPU performance comparison')
bc.yaxis = 'Performance-over-TX2'
bc.BAR_WIDTH = None
platform_list = ['TX2-fp32', 'TitanX-fp32', 'TitanX-int8', 'BitFusion-45nm']
fig_name = os.path.join(fig_dir, 'performance-gpu.pdf')
bc.plot(fig_name, all_fps_df, x_plot='Network', y_plot='fps', bar_plot='Name',
        bar_list=platform_list, add_geomean=True, baseline='TX2-fp32')

# %% [markdown]
# ## Get 2x, 4x, and 8x area performance for bitfusion

# %%
bf_fps_df = pandas.DataFrame(columns=['Name', 'Network', 'fps'])
df_list = []
for factor in [1, 2, 4, 8]:
    config_file = 'bf_e_conf.ini'
    verbose = False
    bf_scaled = Simulator(config_file, verbose)
    bf_scaled.accelerator.M *= factor
    bf_scaled.accelerator.sram['act'] *= factor
    bf_scaled.accelerator.sram['wgt'] *= factor
    bf_scaled.accelerator.sram['out'] *= factor
#     if bf_scaled.accelerator.mem_if_width * factor > 1024:
#         bf_scaled.accelerator.mem_if_width = 1024
#     else:
#         bf_scaled.accelerator.mem_if_width = bf_scaled.accelerator.mem_if_width * factor
#     bf_scaled.accelerator.mem_if_width = bf_scaled.accelerator.mem_if_width * factor
    bf_scaled.accelerator.mem_if_width = 4096
    frequency = bf_scaled.accelerator.frequency
#     print(bf_scaled)
    bf_e_scaled_results = check_pandas_or_run(bf_scaled, bf_e_sim_sweep_df,
                                       bf_e_sim_sweep_csv, batch_size=batch_size)
    bf_e_scaled_results = bf_e_scaled_results.groupby(['Network', 'Batch size']+accelerator_constants,
                                    as_index=False).agg(np.sum)
    bf_e_scaled_results['fps'] = batch_size * frequency / (bf_e_scaled_results.Cycles)
    bf_e_scaled_results['Name'] = 'BitFusion ({}x)'.format(factor)
    bf_e_scaled_results = bf_e_scaled_results[['Name', 'Network', 'fps']]
    df_list.append(bf_e_scaled_results)
    
bf_fps_df = pandas.concat(df_list)
all_fps_df = pandas.concat([all_fps_df, bf_fps_df])
print(all_fps_df)

# %%
bc = BarChart()
bc.LABEL_BAR = True
bc.BAR_WIDTH = None
bc.YAXIS_MAX = 16
bc.FIG_WIDTH = 16
bc.TOP_LABEL_FONTSIZE = 12
bc.LEGEND_FONTSIZE = 16
bc.ISTIMES = True
bc.TOP_ROTATE = True
bc.LEGEND_LOCATION = "upper center"
bc.LEGEND_NCOLUMN = 5
bc.MV_LEGEND_OUTSIDE_Y = 1.6
bc.MV_LEGEND_OUTSIDE_X = 0.5
bc.LOG_SCALE = False

# print('Generating Figure for GPU performance comparison')
bc.yaxis = 'Performance'
bc.BAR_WIDTH = None
fig_name = os.path.join(fig_dir, 'performance-eyeriss-comparision.pdf')
platform_list = ['TX2-fp32', 'TitanX-fp32', 'TitanX-int8', 'BitFusion (8x)']
bc.plot(fig_name, all_fps_df, x_plot='Network', y_plot='fps', bar_plot='Name',
        bar_list=platform_list, add_geomean=True, baseline='TX2-fp32')
